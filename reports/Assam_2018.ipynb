# %%
import pandas as pd

# %%
assam_2018 = pd.read_csv('/home/ubuntu/Downloads/assam.csv')

# %%
assam_2018.drop(['#'], axis = 1, inplace = True)

# %%
assam = assam_2018.drop(['BUDGET ENTITY','HEAD OF ACCOUNT','HEAD DESCRIPTION','HEAD DESCRIPTION ASSAMESE','Sub-Major Head' ,'Minor Head','Sub-Minor Head','Detailed Head','Object Head','Voucher Head','Scheme','Area','Voted/Charged','ACTUALS 2016-17','BUDGET 2017-18','REVISED 2017-18','BUDGET 2018-19','Unnamed: 20','Unnamed: 21'], axis = 1)

# %%
major_head_2018 = assam.groupby(['GRANT NUMBER']).agg(['count','nunique'])

# %%
major_head_2018
# Out:
#                                                    Major Head
#                                                         count nunique
# GRANT NUMBER
# 1 - State Legislature                                      63       7
# 10 - Other Fiscal Service                                  43       1
# 11 - Secretariat and Attached offices                     885       5
# 12 - District Administration                              657       8
# 13 - Treasury & Accounts Administration                   192       2
# 14 - Police                                              2146       2
# 15 - Jails                                                238       3
# 16 - Printing & Stationery                                 68       2
# 17 - Administrative and functional Buildings              104       2
# 18 - Fire Services                                        274       3
# 19 - Vigilance Commission & Others                        184       2
# ...

# %%
major_head_2018.max()
# Out:
# Major Head  count      2217
#             nunique      47
# dtype: int64

# %%
major_head_2018.min()
# Out:
# Major Head  count      1
#             nunique    1
# dtype: int64

# %%
assam_2018_1 = pd.read_csv('/home/ubuntu/Downloads/assam.csv')

# %%
assam_1 = assam_2018_1.drop(['#','GRANT NUMBER','BUDGET ENTITY','HEAD OF ACCOUNT','HEAD DESCRIPTION','HEAD DESCRIPTION ASSAMESE','Minor Head','Sub-Minor Head','Detailed Head','Object Head','Voucher Head','Scheme','Area','Voted/Charged','ACTUALS 2016-17','BUDGET 2017-18','REVISED 2017-18','BUDGET 2018-19','Unnamed: 20','Unnamed: 21'], axis = 1)

# %%
Sub_major_2018 = assam_1.groupby(['Major Head']).agg(['count','nunique'])

# %%
Sub_major_2018
# Out:
#                                                    Sub-Major Head
#                                                             count nunique
# Major Head
# Administration of Justice                                       0       0
# Agricultural Research and Education                           172       5
# Aid Materials & Equipments                                      0       0
# Animal Husbandry                                                0       0
# Appropriation for Reduction or Avoidance of Debt                0       0
# Appropriation to the Contingency Fund                           0       0
# Art and Culture                                                 0       0
# Capital Account                                                 0       0
# Capital Outlay on Agricultural Research and Edu...             11       2
# Capital Outlay on Animal Husbandry                              0       0
# Capital Outlay on Co-operation                                  0       0
# ...

# %%
Sub_major_2018.max()
# Out:
# Sub-Major Head  count      2757
#                 nunique       7
# dtype: int64

# %%
Sub_major_2018.min()
# Out:
# Sub-Major Head  count      0
#                 nunique    0
# dtype: int64

# %%
assam_2018_2 = pd.read_csv('/home/ubuntu/Downloads/assam.csv')

# %%
assam_2 = assam_2018_2.drop(['#','BUDGET ENTITY','HEAD OF ACCOUNT','HEAD DESCRIPTION','HEAD DESCRIPTION ASSAMESE','Minor Head','Sub-Minor Head','Detailed Head','Object Head','Voucher Head','Scheme','Area','Voted/Charged','ACTUALS 2016-17','BUDGET 2017-18','REVISED 2017-18','BUDGET 2018-19','Unnamed: 20','Unnamed: 21'], axis = 1)

# %%
Sub_major_head_2018 = assam_2.groupby(['GRANT NUMBER','Major Head']).agg(['count','nunique'])

# %%
Sub_major_head_2018
# Out:
#                                                                                            Sub-Major Head  \
#                                                                                                     count
# GRANT NUMBER                            Major Head
# 1 - State Legislature                   Capital Outlay on Public Works                                  1
#                                         Capital Outlay on Urban Development                             4
#                                         Loans to Government Servants Etc                                0
#                                         Pension and Other Retirement Benefits                           3
#                                         Public Works                                                    1
#                                         State Legislature                                              51
# ...

# %%
assam_2018_3 = pd.read_csv('/home/ubuntu/Downloads/assam.csv')

# %%
assam_3 = assam_2018_3.drop(['#','GRANT NUMBER','BUDGET ENTITY','HEAD OF ACCOUNT','HEAD DESCRIPTION','HEAD DESCRIPTION ASSAMESE','Major Head','Sub-Minor Head','Detailed Head','Object Head','Voucher Head','Scheme','Area','Voted/Charged','ACTUALS 2016-17','BUDGET 2017-18','REVISED 2017-18','BUDGET 2018-19','Unnamed: 20','Unnamed: 21'], axis = 1)

# %%
minor_2018 = assam_3.groupby(['Sub-Major Head']).agg(['count','nunique'])

# %%
minor_2018
# Out:
#                                                  Minor Head
#                                                       count nunique
# Sub-Major Head
# Adult Education                                          63       4
# Animal Husbandary                                         1       1
# Animal Husbandry                                         15       1
# Art & Culture                                             1       1
# Art and Culture                                          67       7
# Backward Areas                                           86       2
# Bio-energy                                                9       1
# Capital Outlay on Animal Husbandry                        0       0
# Capital Outlay on Public Works                            1       1
# Civil                                                    40       8
# Collection of taxes on commodities & services            24       1
# Consumer Industries                                       1       1
# ...

# %%
minor_2018.max()
# Out:
# Minor Head  count      1278
#             nunique      20
# dtype: int64

# %%
minor_2018.min()
# Out:
# Minor Head  count      0
#             nunique    0
# dtype: int64

# %%
assam_2018_4 = pd.read_csv('/home/ubuntu/Downloads/assam.csv')

# %%
assam_4 = assam_2018_4.drop(['#','BUDGET ENTITY','HEAD OF ACCOUNT','HEAD DESCRIPTION','HEAD DESCRIPTION ASSAMESE','Sub-Minor Head','Detailed Head','Object Head','Voucher Head','Scheme','Area','Voted/Charged','ACTUALS 2016-17','BUDGET 2017-18','REVISED 2017-18','BUDGET 2018-19','Unnamed: 20','Unnamed: 21'], axis = 1)

# %%
minor_head_2018 = assam_4.groupby(['GRANT NUMBER','Major Head','Sub-Major Head']).agg(['count','nunique'])

# %%
minor_head_2018
# Out:
#                                                                                                                                                    Minor Head  \
#                                                                                                                                                         count
# GRANT NUMBER                                 Major Head                                         Sub-Major Head
# 1 - State Legislature                        Capital Outlay on Public Works                     Other Buildings                                             1
#                                              Capital Outlay on Urban Development                State Capital Development                                   4
#                                              Pension and Other Retirement Benefits              Civil                                                       3
# ...

# %%
assam_2018_5 = pd.read_csv('/home/ubuntu/Downloads/assam.csv')

# %%
assam_5 = assam_2018_5.drop(['#','GRANT NUMBER','BUDGET ENTITY','HEAD OF ACCOUNT','HEAD DESCRIPTION','HEAD DESCRIPTION ASSAMESE','Major Head','Sub-Major Head','Detailed Head','Object Head','Voucher Head','Scheme','Area','Voted/Charged','ACTUALS 2016-17','BUDGET 2017-18','REVISED 2017-18','BUDGET 2018-19','Unnamed: 20','Unnamed: 21'], axis = 1)

# %%
Sub_minor_2018 = assam_5.groupby(['Minor Head']).agg(['count','nunique'])

# %%
Sub_minor_2018
# Out:
#                                                    Sub-Minor Head
#                                                             count nunique
# Minor Head
# Administration of Citizenship Act.                             11       1
# Administrative Investigation and Statistics                    32       3
# Advances for Purchase of Motor Conveyance                       1       1
# Advertising and Visual Publicity                               26       3
# Agricultural Economics and Statistics                          35       1
# Agricultural Engineering                                      148       9
# Agricultural Farms                                             31       5
# Agriculture Department                                          6       6
# Agriculture Market & Quality Control                            3       1
# Agriculture Market & Quality control                           75       5
# Agriculture Research                                           17       2
# ...

# %%
Sub_minor_2018.max()
# Out:
# Sub-Minor Head  count      4201
#                 nunique     492
# dtype: int64

# %%
Sub_minor_2018.min()
# Out:
# Sub-Minor Head  count      0
#                 nunique    0
# dtype: int64

# %%
assam_2018_6 = pd.read_csv('/home/ubuntu/Downloads/assam.csv')

# %%
assam_6 = assam_2018_6.drop(['#','BUDGET ENTITY','HEAD OF ACCOUNT','HEAD DESCRIPTION','HEAD DESCRIPTION ASSAMESE','Detailed Head','Object Head','Voucher Head','Scheme','Area','Voted/Charged','ACTUALS 2016-17','BUDGET 2017-18','REVISED 2017-18','BUDGET 2018-19','Unnamed: 20','Unnamed: 21'], axis = 1)

# %%
Sub_minor_head_2018 = assam_6.groupby(['GRANT NUMBER','Major Head','Sub-Major Head','Minor Head']).agg(['count','nunique'])

# %%
Sub_minor_head_2018
# Out:
#                                                                                                                                                                                                       Sub-Minor Head  \
#                                                                                                                                                                                                                count
# GRANT NUMBER                                 Major Head                                         Sub-Major Head                                     Minor Head
# 1 - State Legislature                        Capital Outlay on Public Works                     Other Buildings                                    Other Expenditure                                               1
# ...

# %%
assam_2018_6 = pd.read_csv('/home/ubuntu/Downloads/assam.csv')

# %%
assam_6 = assam_2018_6.drop(['#','GRANT NUMBER','BUDGET ENTITY','HEAD OF ACCOUNT','HEAD DESCRIPTION','HEAD DESCRIPTION ASSAMESE','Major Head','Sub-Major Head','Minor Head','Object Head','Voucher Head','Scheme','Area','Voted/Charged','ACTUALS 2016-17','BUDGET 2017-18','REVISED 2017-18','BUDGET 2018-19','Unnamed: 20','Unnamed: 21'], axis = 1)

# %%
Detailed_2018 = assam_6.groupby(['Sub-Minor Head']).agg(['count','nunique'])

# %%
Detailed_2018
# Out:
#                                                    Detailed Head
#                                                            count nunique
# Sub-Minor Head
# 10 % Central Pool Fund for NE Region                           0       0
# 10 Centres of Excellence                                       0       0
# 10.46% GICI Housing Loan (NIC) 2018-19 75.00                   0       0
# 10.46% GICI Housing Loan (NIC) 2019-20 75.00                   0       0
# 10.46% GICI Housing Loan (NIC) 2022-23 497.00                  0       0
# 10.46% GICI Housing Loan (NIC) 2023-24 557.00                  0       0
# 10.46% GICI Housing Loan (NIC) 2024-25 557.00                  0       0
# 10.46% GICI Housing Loan 2017-18 68.00                         0       0
# 10.46% LICI housing loan,2017-18                               0       0
# 10.46% LICI housing loan,2019-20                               0       0
# 11.50% GICI Fire Fighting Equipments Loan (NIC)...             0       0
# ...

# %%
Detailed_2018.max()
# Out:
# Detailed Head  count      605
#                nunique    602
# dtype: int64

# %%
Detailed_2018.min()
# Out:
# Detailed Head  count      0
#                nunique    0
# dtype: int64

# %%
assam_2018_7 = pd.read_csv('/home/ubuntu/Downloads/assam.csv')

# %%
assam_7 = assam_2018_7.drop(['#','BUDGET ENTITY','HEAD OF ACCOUNT','HEAD DESCRIPTION','HEAD DESCRIPTION ASSAMESE','Object Head','Voucher Head','Scheme','Area','Voted/Charged','ACTUALS 2016-17','BUDGET 2017-18','REVISED 2017-18','BUDGET 2018-19','Unnamed: 20','Unnamed: 21'], axis = 1)

# %%
Detailed_head_2018 = assam_7.groupby(['GRANT NUMBER','Major Head','Sub-Major Head','Minor Head', 'Sub-Minor Head']).agg(['count','nunique'])

# %%
Detailed_head_2018
# Out:
#                                                                                                                                                                                                                                                          Detailed Head  \
#                                                                                                                                                                                                                                                                  count
# GRANT NUMBER                                 Major Head                                         Sub-Major Head                                     Minor Head                                         Sub-Minor Head
# ...

# %%
assam_2018_8 = pd.read_csv('/home/ubuntu/Downloads/assam.csv')

# %%
assam_8 = assam_2018_8.drop(['#','GRANT NUMBER','BUDGET ENTITY','HEAD OF ACCOUNT','HEAD DESCRIPTION','HEAD DESCRIPTION ASSAMESE','Major Head','Sub-Major Head','Minor Head','Sub-Minor Head','Voucher Head','Scheme','Area','Voted/Charged','ACTUALS 2016-17','BUDGET 2017-18','REVISED 2017-18','BUDGET 2018-19','Unnamed: 20','Unnamed: 21'], axis = 1)

# %%
Object_2018 = assam_8.groupby(['Detailed Head']).agg(['count','nunique'])

# %%
Object_2018
# Out:
#                                                    Object Head
#                                                          count nunique
# Detailed Head
# "Biponi": Exhibition for Micro & small Enterpri...           1       1
# "Boneej" : Special grant  scheme for rural Comm...           1       1
# "Karbi People Outside Karbi Anglong" Developmen...           2       1
# "Sarothi": Chief Minister's Start Up Fund                    1       1
# (ii) 8.20% Assam State Development Loan,2017 (R...           1       1
# . Staff Training Hall with Computer peripherals...           1       1
# 10.46% GICI  Housing Loan (2017-18)68.00                     1       1
# 10.46% GICI  Housing Loan (NIC) (2018-19)75.00               1       1
# 10.46% GICI  Housing Loan (NIC) (2019-20)75.00               1       1
# 10.46% GICI  Housing Loan (NIC) (2022-23)497.00              1       1
# 10.46% GICI  Housing Loan (NIC) (2023-24)557.00              1       1
# ...

# %%
Object_2018.max()
# Out:
# Object Head  count      176
#              nunique     19
# dtype: int64

# %%
Object_2018.min()
# Out:
# Object Head  count      0
#              nunique    0
# dtype: int64

# %%
assam_2018_9 = pd.read_csv('/home/ubuntu/Downloads/assam.csv')

# %%
assam_9 = assam_2018_9.drop(['#','BUDGET ENTITY','HEAD OF ACCOUNT','HEAD DESCRIPTION','HEAD DESCRIPTION ASSAMESE','Voucher Head','Scheme','Area','Voted/Charged','ACTUALS 2016-17','BUDGET 2017-18','REVISED 2017-18','BUDGET 2018-19','Unnamed: 20','Unnamed: 21'], axis = 1)

# %%
Object_head_2018 = assam_9.groupby(['GRANT NUMBER','Major Head','Sub-Major Head','Minor Head', 'Sub-Minor Head','Detailed Head']).agg(['count','nunique'])

# %%
Object_head_2018
# Out:
#                                                                                                                                                                                                                                                                                                        Object Head  \
#                                                                                                                                                                                                                                                                                                              count
# GRANT NUMBER                            Major Head                                         Sub-Major Head                                     Minor Head                                         Sub-Minor Head                                     Detailed Head
# ...

# %%
assam_2018_10 = pd.read_csv('/home/ubuntu/Downloads/assam.csv')

# %%
assam_10 = assam_2018_10.drop(['#','GRANT NUMBER','BUDGET ENTITY','HEAD OF ACCOUNT','HEAD DESCRIPTION','HEAD DESCRIPTION ASSAMESE','Major Head','Sub-Major Head','Minor Head','Sub-Minor Head','Detailed Head','Scheme','Area','Voted/Charged','ACTUALS 2016-17','BUDGET 2017-18','REVISED 2017-18','BUDGET 2018-19','Unnamed: 20','Unnamed: 21'], axis = 1)

# %%
Voucher_2018 = assam_10.groupby(['Object Head']).agg(['count','nunique'])

# %%
Voucher_2018
# Out:
#                                                    Voucher Head
#                                                           count nunique
# Object Head
#  outdoor media organisation of events & face li...            0       0
# 5.25% RIDF-XIX-IGN LOAN(2016-17) Rs.9.86 L                    1       1
# Advertising, Sales and Publicity Expenses                   134       4
# Deployment etc                                                0       0
# Grants for creation of Capital Assets                       228       3
# Grants-in-Aid/Contribution/Subsidies                          1       1
# Grants-in-aid General (Non-Salary)                         1184       5
# Grants-in-aid General (Salary)                              173       3
# Hospitality Expenses / Sumptuary Allowances etc              76       3
# Inter Account Transfer                                        0       0
# Investment                                                   41       1
# ...

# %%
Voucher_2018.max()
# Out:
# Voucher Head  count      10135
#               nunique       50
# dtype: int64

# %%
Voucher_2018.min()
# Out:
# Voucher Head  count      0
#               nunique    0
# dtype: int64

# %%
assam_2018_11 = pd.read_csv('/home/ubuntu/Downloads/assam.csv')

# %%
assam_11 = assam_2018_11.drop(['#','BUDGET ENTITY','HEAD OF ACCOUNT','HEAD DESCRIPTION','HEAD DESCRIPTION ASSAMESE','Scheme','Area','Voted/Charged','ACTUALS 2016-17','BUDGET 2017-18','REVISED 2017-18','BUDGET 2018-19','Unnamed: 20','Unnamed: 21'], axis = 1)

# %%
Voucher_head_2018 = assam_11.groupby(['GRANT NUMBER','Major Head','Sub-Major Head','Minor Head', 'Sub-Minor Head','Detailed Head','Object Head']).agg(['count','nunique'])

# %%
Voucher_head_2018
# Out:
#                                                                                                                                                                                                                                                                                                                                                        Voucher Head  \
#                                                                                                                                                                                                                                                                                                                                                               count
# ...

# %%
assam_2018_12 = pd.read_csv('/home/ubuntu/Downloads/assam.csv')

# %%
assam_12 = assam_2018_12.drop(['#','GRANT NUMBER','BUDGET ENTITY','HEAD OF ACCOUNT','HEAD DESCRIPTION','HEAD DESCRIPTION ASSAMESE','Major Head','Sub-Major Head','Minor Head','Sub-Minor Head','Detailed Head','Object Head','Area','Voted/Charged','ACTUALS 2016-17','BUDGET 2017-18','REVISED 2017-18','BUDGET 2018-19','Unnamed: 20','Unnamed: 21'], axis = 1)

# %%
Scheme_2018 = assam_12.groupby(['Voucher Head']).agg(['count','nunique'])

# %%
Scheme_2018
# Out:
#                                                    Scheme
#                                                     count nunique
# Voucher Head
# Advance Payment to Advocate for filing of SLP i...      1       1
# Affiliation fees                                       29       2
# Aid Materials                                           5       4
# Air lifting                                             3       2
# Anganwadi Helper                                        1       1
# Anganwadi Worker                                        1       1
# Arrear Salary/DA                                      536       4
# Arrears                                               144       6
# Asset Maintenance                                      43       3
# Award Money / Award in kind                            51       2
# Batta Allowance                                        22       1
# Books and Periodicals                                 196       2
# ...

# %%
Scheme_2018.max()
# Out:
# Scheme  count      6141
#         nunique      25
# dtype: int64

# %%
Scheme_2018.min()
# Out:
# Scheme  count      1
#         nunique    1
# dtype: int64

# %%
assam_2018_13 = pd.read_csv('/home/ubuntu/Downloads/assam.csv')

# %%
assam_13 = assam_2018_13.drop(['#','BUDGET ENTITY','HEAD OF ACCOUNT','HEAD DESCRIPTION','HEAD DESCRIPTION ASSAMESE','Area','Voted/Charged','ACTUALS 2016-17','BUDGET 2017-18','REVISED 2017-18','BUDGET 2018-19','Unnamed: 20','Unnamed: 21'], axis = 1)

# %%
Scheme_head_2018 = assam_13.groupby(['GRANT NUMBER','Major Head','Sub-Major Head','Minor Head', 'Sub-Minor Head','Detailed Head','Object Head','Voucher Head']).agg(['count','nunique'])

# %%
Scheme_head_2018
# Out:
#                                                                                                                                                                                                                                                                                                                                                                             Scheme  \
#                                                                                                                                                                                                                                                                                                                                                                              count
# ...

# %%
assam_2018_14 = pd.read_csv('/home/ubuntu/Downloads/assam.csv')

# %%
assam_14 = assam_2018_14.drop(['#','GRANT NUMBER','BUDGET ENTITY','HEAD OF ACCOUNT','HEAD DESCRIPTION','HEAD DESCRIPTION ASSAMESE','Major Head','Sub-Major Head','Minor Head','Sub-Minor Head','Detailed Head','Object Head','Voucher Head','Voted/Charged','ACTUALS 2016-17','BUDGET 2017-18','REVISED 2017-18','BUDGET 2018-19','Unnamed: 20','Unnamed: 21'], axis = 1)

# %%
Area_2018 = assam_14.groupby(['Scheme']).agg(['count','nunique'])

# %%
Area_2018
# Out:
#                                                      Area
#                                                     count nunique
# Scheme
# Centrally Sponsored Scheme                            705       5
# Committed Liabilities                                   1       1
# Establishment Expenditure-Central Share               252       4
# Establishment Expenditure-Six Schedule Area           124       3
# Establishmet Expenditure                            22956       7
# Establishmet Expenditure-State Share                    9       1
# Externally Aided Projects                              17       1
# Externally Aided Projects-State Share                  14       1
# Interest Payment                                        1       1
# Machinery and Equipment                                 1       1
# Others                                                  4       3
# Plan                                                    2       1
# ...

# %%
Area_2018.max()
# Out:
# Area  count      22956
#       nunique        7
# dtype: int64

# %%
Area_2018.min()
# Out:
# Area  count      1
#       nunique    1
# dtype: int64

# %%
assam_2018_15 = pd.read_csv('/home/ubuntu/Downloads/assam.csv')

# %%
assam_15 = assam_2018_15.drop(['#','BUDGET ENTITY','HEAD OF ACCOUNT','HEAD DESCRIPTION','HEAD DESCRIPTION ASSAMESE','Voted/Charged','ACTUALS 2016-17','BUDGET 2017-18','REVISED 2017-18','BUDGET 2018-19','Unnamed: 20','Unnamed: 21'], axis = 1)

# %%
Area_head_2018 = assam_15.groupby(['GRANT NUMBER','Major Head','Sub-Major Head','Minor Head', 'Sub-Minor Head','Detailed Head','Object Head','Voucher Head','Scheme']).agg(['count','nunique'])

# %%
Area_head_2018
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                 Area  \
#                                                                                                                                                                                                                                                                                                                                                                                                                                count
# ...

# %%
assam_2018_16 = pd.read_csv('/home/ubuntu/Downloads/assam.csv')

# %%
assam_16 = assam_2018_16.drop(['#','GRANT NUMBER','BUDGET ENTITY','HEAD OF ACCOUNT','HEAD DESCRIPTION','HEAD DESCRIPTION ASSAMESE','Major Head','Sub-Major Head','Minor Head','Sub-Minor Head','Detailed Head','Object Head','Voucher Head','Scheme','ACTUALS 2016-17','BUDGET 2017-18','REVISED 2017-18','BUDGET 2018-19','Unnamed: 20','Unnamed: 21'], axis = 1)

# %%
Voted_Charged_2018 = assam_16.groupby(['Area']).agg(['count','nunique'])

# %%
Voted_Charged_2018
# Out:
#                                       Voted/Charged
#                                               count nunique
# Area
# Bodoland Entrusted                             2197       1
# Bodoland Non-entrusted                          318       2
# Centrally Sponsored Scheme                        3       1
# Establishmet Expenditure                          1       1
# General Area                                  19888       2
# Karbi Anglong Entrusted                        1864       1
# Karbi Anglong Non-entrusted                     721       2
# North Cachar Entrusted                         1459       1
# North Cachar Non-entrusted                      610       2
# Others                                            1       1
# State Own Priority Scheme-General                 2       1
# State Own Priority Scheme-State Share             1       1

# %%
Voted_Charged_2018.max()
# Out:
# Voted/Charged  count      19888
#                nunique        2
# dtype: int64

# %%
Voted_Charged_2018.min()
# Out:
# Voted/Charged  count      1
#                nunique    1
# dtype: int64

# %%
assam_2018_17 = pd.read_csv('/home/ubuntu/Downloads/assam.csv')

# %%
assam_17 = assam_2018_17.drop(['#','BUDGET ENTITY','HEAD OF ACCOUNT','HEAD DESCRIPTION','HEAD DESCRIPTION ASSAMESE','ACTUALS 2016-17','BUDGET 2017-18','REVISED 2017-18','BUDGET 2018-19','Unnamed: 20','Unnamed: 21'], axis = 1)

# %%
Voted_Charged_head_2018 = assam_17.groupby(['GRANT NUMBER','Major Head','Sub-Major Head','Minor Head', 'Sub-Minor Head','Detailed Head','Object Head','Voucher Head','Scheme','Area']).agg(['count','nunique'])

# %%
Voted_Charged_head_2018
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                         Voted/Charged  \
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                 count
# ...
