# %%
import pandas as pd

# %%
#assam_2018 = budget data of assam for year 2018
assam_2018 = pd.read_csv('./assam.csv')

# %%
major_head_2018 = assam_2018[['GRANT NUMBER','Major Head']].groupby(['GRANT NUMBER']).agg(['count','nunique'])

# %%
major_head_2018
# Out:
#                                                    Major Head
#                                                         count nunique
# GRANT NUMBER
# 1 - State Legislature                                      63       7
# 10 - Other Fiscal Service                                  43       1
# 11 - Secretariat and Attached offices                     885       5
# 12 - District Administration                              657       8
# 13 - Treasury & Accounts Administration                   192       2
# 14 - Police                                              2146       2
# 15 - Jails                                                238       3
# 16 - Printing & Stationery                                 68       2
# 17 - Administrative and functional Buildings              104       2
# 18 - Fire Services                                        274       3
# 19 - Vigilance Commission & Others                        184       2
# ...

# %%
major_head_2018.max()
# Out:
# Major Head  count      2217
#             nunique      47
# dtype: int64

# %%
major_head_2018.min()
# Out:
# Major Head  count      1
#             nunique    1
# dtype: int64

# %%
Sub_major_head_2018 = assam_2018[['GRANT NUMBER','Major Head', 'Sub-Major Head']].groupby(['GRANT NUMBER','Major Head']).agg(['count','nunique'])

# %%
Sub_major_head_2018
# Out:
#                                                                                            Sub-Major Head  \
#                                                                                                     count
# GRANT NUMBER                            Major Head
# 1 - State Legislature                   Capital Outlay on Public Works                                  1
#                                         Capital Outlay on Urban Development                             4
#                                         Loans to Government Servants Etc                                0
#                                         Pension and Other Retirement Benefits                           3
#                                         Public Works                                                    1
#                                         State Legislature                                              51
# ...

# %%
Sub_major_head_2018.max()
# Out:
# Sub-Major Head  count      1938
#                 nunique       7
# dtype: int64

# %%
Sub_major_head_2018.min()
# Out:
# Sub-Major Head  count      0
#                 nunique    0
# dtype: int64

# %%
minor_head_2018 = assam_2018[['GRANT NUMBER','Major Head','Sub-Major Head','Minor Head']].groupby(['GRANT NUMBER','Major Head','Sub-Major Head']).agg(['count','nunique'])

# %%
minor_head_2018
# Out:
#                                                                                                                                                    Minor Head  \
#                                                                                                                                                         count
# GRANT NUMBER                                 Major Head                                         Sub-Major Head
# 1 - State Legislature                        Capital Outlay on Public Works                     Other Buildings                                             1
#                                              Capital Outlay on Urban Development                State Capital Development                                   4
#                                              Pension and Other Retirement Benefits              Civil                                                       3
# ...

# %%
minor_head_2018.max()
# Out:
# Minor Head  count      1089
#             nunique      11
# dtype: int64

# %%
minor_head_2018.min()
# Out:
# Minor Head  count      0
#             nunique    0
# dtype: int64

# %%
Sub_minor_head_2018 = assam_2018[['GRANT NUMBER','Major Head','Sub-Major Head','Minor Head','Sub-Minor Head']].groupby(['GRANT NUMBER','Major Head','Sub-Major Head','Minor Head']).agg(['count','nunique'])

# %%
Sub_minor_head_2018
# Out:
#                                                                                                                                                                                                       Sub-Minor Head  \
#                                                                                                                                                                                                                count
# GRANT NUMBER                                 Major Head                                         Sub-Major Head                                     Minor Head
# 1 - State Legislature                        Capital Outlay on Public Works                     Other Buildings                                    Other Expenditure                                               1
# ...

# %%
Sub_minor_head_2018.max()
# Out:
# Sub-Minor Head  count      712
#                 nunique     48
# dtype: int64

# %%
Sub_minor_head_2018.min()
# Out:
# Sub-Minor Head  count      0
#                 nunique    0
# dtype: int64

# %%
Detailed_head_2018 = assam_2018[['GRANT NUMBER','Major Head','Sub-Major Head','Minor Head','Sub-Minor Head','Detailed Head']].groupby(['GRANT NUMBER','Major Head','Sub-Major Head','Minor Head', 'Sub-Minor Head']).agg(['count','nunique'])

# %%
Detailed_head_2018
# Out:
#                                                                                                                                                                                                                                                          Detailed Head  \
#                                                                                                                                                                                                                                                                  count
# GRANT NUMBER                                 Major Head                                         Sub-Major Head                                     Minor Head                                         Sub-Minor Head
# ...

# %%
Detailed_head_2018.max()
# Out:
# Detailed Head  count      605
#                nunique    602
# dtype: int64

# %%
Detailed_head_2018.min()
# Out:
# Detailed Head  count      0
#                nunique    0
# dtype: int64

# %%
Object_head_2018 = assam_2018[['GRANT NUMBER','Major Head','Sub-Major Head','Minor Head','Sub-Minor Head','Detailed Head','Object Head']].groupby(['GRANT NUMBER','Major Head','Sub-Major Head','Minor Head', 'Sub-Minor Head','Detailed Head']).agg(['count','nunique'])

# %%
Object_head_2018
# Out:
#                                                                                                                                                                                                                                                                                                        Object Head  \
#                                                                                                                                                                                                                                                                                                              count
# GRANT NUMBER                            Major Head                                         Sub-Major Head                                     Minor Head                                         Sub-Minor Head                                     Detailed Head
# ...

# %%
Object_head_2018.max()
# Out:
# Object Head  count      74
#              nunique    14
# dtype: int64

# %%
Object_head_2018.min()
# Out:
# Object Head  count      0
#              nunique    0
# dtype: int64

# %%
Voucher_head_2018 = assam_2018[['GRANT NUMBER','Major Head','Sub-Major Head','Minor Head','Sub-Minor Head','Detailed Head','Object Head','Voucher Head']].groupby(['GRANT NUMBER','Major Head','Sub-Major Head','Minor Head', 'Sub-Minor Head','Detailed Head','Object Head']).agg(['count','nunique'])

# %%
Voucher_head_2018
# Out:
#                                                                                                                                                                                                                                                                                                                                                        Voucher Head  \
#                                                                                                                                                                                                                                                                                                                                                               count
# ...

# %%
Voucher_head_2018.max()
# Out:
# Voucher Head  count      30
#               nunique    13
# dtype: int64

# %%
Voucher_head_2018.min()
# Out:
# Voucher Head  count      0
#               nunique    0
# dtype: int64
