# %%
import pandas as pd

# %%
#Expenditure data of assam for year 2017
assam_exp_2017 = pd.read_csv('./assam_exp_2017.csv')

# %%
major_head_2017 = assam_exp_2017[['Grant','Major Head']].groupby(['Grant']).agg(['count','nunique'])

# %%
major_head_2017
# Out:
#                                                    Major Head
#                                                         count nunique
# Grant
# 1-State Legislature                                        71       7
# 10-Other Fiscal Service                                    41       1
# 11-Secretariat and Attached offices                       827       5
# 12-District Administration                                584       7
# 13-Treasury & Accounts Administration                     180       2
# 14-Police                                                1940       2
# 15-Jails                                                  150       2
# 16-Printing & Stationery                                   81       2
# 17-Administrative and functional Buildings                156       2
# 18-Fire Services                                          144       3
# 19-Vigilance Commission & Others                          155       1
# ...

# %%
major_head_2017.max()
# Out:
# Major Head  count      2472
#             nunique      49
# dtype: int64

# %%
major_head_2017.min()
# Out:
# Major Head  count      1
#             nunique    1
# dtype: int64

# %%
Sub_major_head_2017 = assam_exp_2017[['Grant','Major Head','Sub Major Head']].groupby(['Grant','Major Head']).agg(['count','nunique'])

# %%
Sub_major_head_2017
# Out:
#                                                       Sub Major Head
#                                                                count nunique
# Grant                                      Major Head
# 1-State Legislature                        2011.0                 52       1
#                                            2058.0                  1       1
#                                            2059.0                  3       1
#                                            2071.0                  4       1
#                                            4059.0                  1       1
#                                            4217.0                  8       1
#                                            7610.0                  2       1
# 10-Other Fiscal Service                    2047.0                 41       1
# 11-Secretariat and Attached offices        2052.0                432       1
#                                            2251.0                103       1
# ...

# %%
Sub_major_head_2017.max()
# Out:
# Sub Major Head  count      1899
#                 nunique       7
# dtype: int64

# %%
Sub_major_head_2017.min()
# Out:
# Sub Major Head  count      1
#                 nunique    1
# dtype: int64

# %%
minor_head_2017 = assam_exp_2017[['Grant','Major Head','Sub Major Head','Minor Head']].groupby(['Grant','Major Head','Sub Major Head']).agg(['count','nunique'])

# %%
minor_head_2017
# Out:
#                                                                      Minor Head  \
#                                                                           count
# Grant                                      Major Head Sub Major Head
# 1-State Legislature                        2011.0     2.0                    52
#                                            2058.0     0.0                     1
#                                            2059.0     60.0                    3
#                                            2071.0     1.0                     4
#                                            4059.0     60.0                    1
#                                            4217.0     1.0                     8
#                                            7610.0     0.0                     2
# 10-Other Fiscal Service                    2047.0     0.0                    41
# 11-Secretariat and Attached offices        2052.0     0.0                   432
# ...

# %%
minor_head_2017.max()
# Out:
# Minor Head  count      1899
#             nunique      28
# dtype: int64

# %%
minor_head_2017.min()
# Out:
# Minor Head  count      1
#             nunique    1
# dtype: int64

# %%
Sub_head_2017 = assam_exp_2017[['Grant','Major Head','Sub Major Head','Minor Head','Sub Head']].groupby(['Grant','Major Head','Sub Major Head','Minor Head']).agg(['count','nunique'])

# %%
Sub_head_2017
# Out:
#                                                                          Sub Head  \
#                                                                             count
# Grant                               Major Head Sub Major Head Minor Head
# 1-State Legislature                 2011.0     2.0            101              34
#                                                               103              16
#                                                               800               2
#                                     2058.0     0.0            800               1
#                                     2059.0     60.0           103               3
#                                     2071.0     1.0            111               4
#                                     4059.0     60.0           800               1
#                                     4217.0     1.0            051               8
# ...

# %%
Sub_head_2017.max()
# Out:
# Sub Head  count      769
#           nunique    292
# dtype: int64

# %%
Sub_head_2017.min()
# Out:
# Sub Head  count      1
#           nunique    1
# dtype: int64

# %%
Sub_Sub_head_2017 = assam_exp_2017[['Grant','Major Head','Sub Major Head','Minor Head','Sub Head','Sub Sub Head']].groupby(['Grant','Major Head','Sub Major Head','Minor Head','Sub Head']).agg(['count','nunique'])

# %%
Sub_Sub_head_2017
# Out:
#                                                                                   Sub Sub Head  \
#                                                                                          count
# Grant                               Major Head Sub Major Head Minor Head Sub Head
# 1-State Legislature                 2011.0     2.0            101        0004               27
#                                                                          0012                7
#                                                               103        0000               16
#                                                               800        3165                2
#                                     2058.0     0.0            800        1725                1
#                                     2059.0     60.0           103        1726                3
#                                     2071.0     1.0            111        0000                4
# ...

# %%
Sub_Sub_head_2017 .max()
# Out:
# Sub Sub Head  count      509
#               nunique    509
# dtype: int64

# %%
Sub_Sub_head_2017.min()
# Out:
# Sub Sub Head  count      1
#               nunique    1
# dtype: int64

# %%
Detail_head_2017 = assam_exp_2017[['Grant','Major Head','Sub Major Head','Minor Head','Sub Head','Sub Sub Head','Detail head']].groupby(['Grant','Major Head','Sub Major Head','Minor Head','Sub Head','Sub Sub Head']).agg(['count','nunique'])

# %%
Detail_head_2017
# Out:
#                                                                                                Detail head  \
#                                                                                                      count
# Grant                               Major Head Sub Major Head Minor Head Sub Head Sub Sub Head
# 1-State Legislature                 2011.0     2.0            101        0004     000                   27
#                                                                          0012     000                    7
#                                                               103        0000     000                   16
#                                                               800        3165     000                    2
#                                     2058.0     0.0            800        1725     000                    1
#                                     2059.0     60.0           103        1726     000                    3
# ...

# %%
Detail_head_2017.max()
# Out:
# Detail head  count      156
#              nunique     16
# dtype: int64

# %%
Detail_head_2017.min()
# Out:
# Detail head  count      1
#              nunique    1
# dtype: int64

# %%
Sub_detail_head_2017 = assam_exp_2017[['Grant','Major Head','Sub Major Head','Minor Head','Sub Head','Sub Sub Head','Detail head','Sub detail Head']].groupby(['Grant','Major Head','Sub Major Head','Minor Head','Sub Head','Sub Sub Head', 'Detail head']).agg(['count','nunique'])

# %%
Sub_detail_head_2017
# Out:
#                                                                                                          Sub detail Head  \
#                                                                                                                    count
# Grant                             Major Head Sub Major Head Minor Head Sub Head Sub Sub Head Detail head
# 1-State Legislature               2011.0     2.0            101        0004     000          1.0                      12
#                                                                                              3.0                       2
#                                                                                              4.0                       2
#                                                                                              11.0                      2
#                                                                                              16.0                      2
# ...

# %%
Sub_detail_head_2017.max()
# Out:
# Sub detail Head  count      54
#                  nunique    30
# dtype: int64

# %%
Sub_detail_head_2017.min()
# Out:
# Sub detail Head  count      1
#                  nunique    1
# dtype: int64
