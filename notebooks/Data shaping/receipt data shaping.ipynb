# %%
import pandas as pd

# %%
assam_receipt = pd.read_csv('/home/ubuntu/civicdatalab/assamprocessedreceipts.csv')

# %%
Voucher_head_receipt = assam_receipt[['Major Head','Sub-Major Head','Minor Head','Sub-Minor Head','Detailed Head']].groupby(['Major Head','Sub-Major Head','Minor Head', 'Sub-Minor Head']).agg(['count','nunique'])

# %%
Voucher_head_receipt
# Out:
#                                                                                                                                                                                                    Detailed Head  \
#                                                                                                                                                                                                            count
# Major Head                                Sub-Major Head                                     Minor Head                                         Sub-Minor Head
# Central Goods and Services Tax (CGST)     Null                                               Share of Net Proceeds Assigned to States           Null                                                           1
# ...

# %%
Voucher_head_receipt.max()
# Out:
# Detailed Head  count      24
#                nunique    24
# dtype: int64

# %%
Voucher_head_receipt.min()
# Out:
# Detailed Head  count      0
#                nunique    0
# dtype: int64
